# %%
import os
import logging
from urllib.parse import urljoin
import requests
from bs4 import BeautifulSoup
import json

# %%
logging.basicConfig(
    format='%(asctime)s %(levelname)s:%(message)s',
    level=logging.INFO)

class MusicCrawler:

    def __init__(self, urls=[]):
        self.headers = {
          'User-Agent': 'Mozilla/5.0 (Macintosh; Intel Mac OS X 10.15; rv:109.0) Gecko/20100101 Firefox/109.0',
        }
        self.decade = 50
        self.visited_urls = []
        self.urls_to_visit = urls
        self.current_year = 0
        self.music_list = []
        self.year_list = []
        self.top_music_by_year = []
        self.add_url_to_visit()

    def add_url_to_visit(self):
        url = self.urls_to_visit.pop(0)
        for i in range(2021,2023):
          new_url = url + str(i) + '/'
          self.year_list.append(i)
          self.urls_to_visit.append(new_url)            
        self.current_year = self.year_list.pop(0)
    def download_url(self, url):
        return requests.get(url, headers=self.headers)

    def get_linked_urls(self, url, html):
        soup = BeautifulSoup(html, 'html.parser')
        for link in soup.find_all('a'):
            path = link.get('href')
            if path and path.startswith('/'):
                path = urljoin(url, path)
            yield path
            
    def parse_list(self, parser, text):
        tag = parser.find(class_='lista') 
        index = 1
        for list_item in tag.find_all('li'):
          content = list_item.text
          content = content.split(' – ')
          self.music_list.append(
              dict(rank = str(index),
                   name = content[0],
                   author = content[1]
                  ))
          index += 1
          
    def assembly_and_release(self):
        top_music = {
            'year' : self.current_year,
            'music_list' : self.music_list
        }
        prev_year = self.current_year
        if len(self.year_list) > 0:
          self.current_year = self.year_list.pop(0)
        self.top_music_by_year.append(top_music)
        self.music_list = []
        if prev_year % 10 == 0:
          filename = 'out' +'/' + str(self.decade) + '.json'
          self.dump(filename)
        if len(self.year_list) == 0:
          filename = 'out/20.json'
          self.dump(filename)          
        
    def dump(self, filename):
        year = str(self.current_year)
        decade = int(year[2:4])
        decade = decade - (decade % 10)
        self.decade = decade
        #with open(filename, "w+") as outfile:
          #json.dump(self.top_music_by_year, outfile)
        #self.top_music_by_year.clear()

    def crawl(self, url):      
        html = self.download_url(url)
        soup = BeautifulSoup(html.text, 'html.parser')
        self.parse_list(soup, html.text)
        self.assembly_and_release()
        
    def run(self):
        while self.urls_to_visit:
            url = self.urls_to_visit.pop(0)
            logging.info(f'Crawling: {url}')
            try:
                self.crawl(url)
            except Exception:
                logging.exception(f'Failed to crawl: {url}')
            finally:
                self.visited_urls.append(url)
if __name__ == '__main__':
    Crawler(urls=['https://maistocadas.mus.br/']).run()
# Out:
# 2023-02-28 13:43:37,843 INFO:Crawling: https://maistocadas.mus.br/2021/
# 2023-02-28 13:43:38,330 INFO:Crawling: https://maistocadas.mus.br/2022/

# %%
23 % 10
# Out:
# 3

# %%
'''
To-do:
  - Buscar letra à partir dos termos, filtrando caracteres especiais (como &, #);
  - 
  https://www.letras.mus.br/?q=Cacha%C3%A7a%20Carmen%20Costa%20%26%20Col%C3%A9
  https://www.letras.mus.br/?q=Cachaça Carmen Costa %26 Colé
  
  Para cada arquivo de década:
    abrir
    montar string de busca
    filtrar caracteres especiais # (&,#)
    fazer request de busca: 
      fazer request para o resultado mais relevante se a busca retornou resultados
      fazer parse do html para filtrar texto de letra
      concatenar ao JSON de letras com informações, ano, letra, década, e posição no ranking de mais ouvidas.
      Filtrar Músicas duplicadas!!! (Uma mesma música pode entrar na lista de mais ouvidas múltiplas vezes)
      
      Analisar estatísticas.
      Quantas músicas repetiram-se anos seguidos, etc..

  Filtro de letras em inglês:
  para cada letra faça:
    escolha aleatoriamente 10 palavras com número de caracteres superior à 2
    fazer uma busca: se 50% das palavras estiverem presentes no dicionário faça: # Definir essa taxa.
    registrar nome da música, ano e colocação em arquivo JSON contendo as músicas com indicativo.
    
    Analisar quantidade resultante
    
'''

# %%
class LyricsCrawler:
    def __init__(self, urls=[]):

    def assembly_dictionary(self):
      files = os.listdir('out/')
      # Deserialize JSON
      music_dictionary = []
      for f in files: 
        with open('out/'+f, "r") as read_file:
          data = json.load(read_file)
          for i in range(len(data)):
            year = data[i]['year']
      
      # Todo: Remove duplicates at insertion in the dictionary. Chave = nome da música?
      # Create an empty field to storage the lyrics.
      # 
      
    def crawl(self, url):      
        html = self.download_url(url)
        soup = BeautifulSoup(html.text, 'html.parser')
        #self.parse_list(soup, html.text)
        
    def run(self):
        while self.urls_to_visit:
            url = self.urls_to_visit.pop(0)
            logging.info(f'Crawling: {url}')
            try:
                self.crawl(url)
            except Exception:
                logging.exception(f'Failed to crawl: {url}')
            finally:
                self.visited_urls.append(url)
if __name__ == '__main__':
    Crawler(urls=['https://maistocadas.mus.br/']).run()

# %%
f = '60.json'
with open('out/'+f, "r") as read_file:
  data = json.load(read_file)
print(data)
# Out:
# [{'year': 1961, 'music_list': [{'rank': '1', 'name': 'Palhaçada', 'author': 'Dóris Monteiro'}, {'rank': '2', 'name': 'Blue Moon', 'author': 'The Marcels'}, {'rank': '3', 'name': 'Bat Masterson', 'author': 'Carlos Gonzaga'}, {'rank': '4', 'name': 'Faz-me Rir', 'author': 'Edith Veiga'}, {'rank': '5', 'name': 'Biquíni De Bolinha Amarelinha', 'author': 'Ronnie Cord'}, {'rank': '6', 'name': 'Its Now Or Never', 'author': 'Elvis Presley'}, {'rank': '7', 'name': 'Surrender', 'author': 'Elvis Presley'}, {'rank': '8', 'name': 'Negue', 'author': 'Nelson Gonçalves'}, {'rank': '9', 'name': 'Maringá', 'author': 'Carlos Galhardo'}, {'rank': '10', 'name': 'Ninguém É De Ninguém', 'author': 'Cauby Peixoto'}, {'rank': '11', 'name': 'Boato', 'author': 'Elza Soares'}, {'rank': '12', 'name': 'Solidão', 'author': 'Núbia Lafayette'}, {'rank': '13', 'name': 'Ansiedad', 'author': 'Nat King Cole'}, {'rank': '14', 'name': 'Devaneio', 'author': 'Djalma Ferreira'}, {'rank': '15', 'name': 'The Twist', 'author': 'Chubby Checker'}, {'rank': '16', 'name': 'Mulata Assanhada', 'author': 'Miltinho'}, {'rank': '17', 'name': 'calcutta', 'author': 'Lawrence Welk'}, {'rank': '18', 'name': 'Look For A Star', 'author': 'Garry Miles'}, {'rank': '19', 'name': 'Exodus', 'author': 'Ferrante & Teicher'}, {'rank': '20', 'name': 'Apache', 'author': 'The Jet Black’s'}, {'rank': '21', 'name': 'La Barca', 'author': 'Trio Cristal'}, {'rank': '22', 'name': 'O Barquinho', 'author': 'João Gilberto'}, {'rank': '23', 'name': 'Runaway', 'author': 'Del Shannon'}, {'rank': '24', 'name': 'My Home Town', 'author': 'Paul Anka'}, {'rank': '25', 'name': 'Corinna, corinna', 'author': 'Demetrius'}, {'rank': '26', 'name': 'Coração De Luto', 'author': 'Teixerinha'}, {'rank': '27', 'name': 'Agora', 'author': 'Alcides Gerardi'}, {'rank': '28', 'name': 'Perdão Para Dois', 'author': 'Cauby Peixoto'}, {'rank': '29', 'name': 'Perdoa-me Pelo Bem, Que Te Quero', 'author': 'Orlando Dias'}, {'rank': '30', 'name': 'Poema Do Adeus', 'author': 'Miltinho'}, {'rank': '31', 'name': 'Bata Baby', 'author': 'Wilson Miranda'}, {'rank': '32', 'name': 'Wonderland By Night', 'author': 'Bert Kaempfert'}, {'rank': '33', 'name': 'Ternura Antiga', 'author': 'Tito Madi'}, {'rank': '34', 'name': 'Só Vou De Mulher', 'author': 'Os Cariocas'}, {'rank': '35', 'name': 'Água De Beber', 'author': 'Isaura Garcia'}, {'rank': '36', 'name': 'Pony Time', 'author': 'Chubby Checker'}, {'rank': '37', 'name': 'Never On Sunday', 'author': 'Melina Mercouri'}, {'rank': '38', 'name': 'Michael', 'author': 'The Highwaymen'}, {'rank': '39', 'name': 'G.i.blues', 'author': 'Elvis Presley'}, {'rank': '40', 'name': 'Aliança', 'author': 'Fernando Barreto'}, {'rank': '41', 'name': 'Marcha Do Pintinho', 'author': 'Emilinha Borba'}, {'rank': '42', 'name': 'A Noiva', 'author': 'Angela Maria'}, {'rank': '43', 'name': 'Ninguém Chora Por Mim', 'author': 'Moacyr Franco'}, {'rank': '44', 'name': 'O Amor Em Paz', 'author': 'João Gilberto'}, {'rank': '45', 'name': 'Olga', 'author': 'Os Cometas'}, {'rank': '46', 'name': 'Wheels', 'author': 'String-a-longs'}, {'rank': '47', 'name': 'O Amor Em Paz', 'author': 'João Gilberto'}, {'rank': '48', 'name': 'Amor Impossível', 'author': 'Carlos Nobre'}, {'rank': '49', 'name': 'Cadeira Vazia', 'author': 'Elza Soares'}, {'rank': '50', 'name': 'Dinah', 'author': 'Clério Morais'}, {'rank': '51', 'name': 'Abismo De Rosas', 'author': 'Dilermando Reis'}, {'rank': '52', 'name': 'Ironia', 'author': 'Carlos Nobre'}, {'rank': '53', 'name': 'Apache', 'author': 'The Shadows'}, {'rank': '54', 'name': 'Tenho Ciúme De Tudo', 'author': 'orlando Dias'}, {'rank': '55', 'name': 'Justiça De Deus', 'author': 'Leila Silva'}, {'rank': '56', 'name': 'Lágrimas de palhaço', 'author': 'Osny Silva'}, {'rank': '57', 'name': 'Never On Sunday', 'author': 'Don Costa And His Orchestra And Chorus'}, {'rank': '58', 'name': 'Paciência', 'author': 'Osny Silva'}, {'rank': '59', 'name': 'Green Fields', 'author': 'Os Cantores De Ébano'}, {'rank': '60', 'name': 'Mar ...

# %%
data[0]['music_list']
# Out:
# [{'rank': '1', 'name': 'Palhaçada', 'author': 'Dóris Monteiro'},
#  {'rank': '2', 'name': 'Blue Moon', 'author': 'The Marcels'},
#  {'rank': '3', 'name': 'Bat Masterson', 'author': 'Carlos Gonzaga'},
#  {'rank': '4', 'name': 'Faz-me Rir', 'author': 'Edith Veiga'},
#  {'rank': '5',
#   'name': 'Biquíni De Bolinha Amarelinha',
#   'author': 'Ronnie Cord'},
#  {'rank': '6', 'name': 'Its Now Or Never', 'author': 'Elvis Presley'},
#  {'rank': '7', 'name': 'Surrender', 'author': 'Elvis Presley'},
#  {'rank': '8', 'name': 'Negue', 'author': 'Nelson Gonçalves'},
#  {'rank': '9', 'name': 'Maringá', 'author': 'Carlos Galhardo'},
#  {'rank': '10', 'name': 'Ninguém É De Ninguém', 'author': 'Cauby Peixoto'},
#  {'rank': '11', 'name': 'Boato', 'author': 'Elza Soares'},
#  {'rank': '12', 'name': 'Solidão', 'author': 'Núbia Lafayette'},
#  {'rank': '13', 'name': 'Ansiedad', 'author': 'Nat King Cole'},
#  {'rank': '14', 'name': 'Devaneio', 'author': 'Djalma Ferreira'},
#  {'rank': '15', 'name': 'The Twist', 'author': 'Chubby Checker'},
#  {'rank': '16', 'name': 'Mulata Assanhada', 'author': 'Miltinho'},
#  {'rank': '17', 'name': 'calcutta', 'author': 'Lawrence Welk'},
#  {'rank': '18', 'name': 'Look For A Star', 'author': 'Garry Miles'},
#  {'rank': '19', 'name': 'Exodus', 'author': 'Ferrante & Teicher'},
#  {'rank': '20', 'name': 'Apache', 'author': 'The Jet Black’s'},
#  {'rank': '21', 'name': 'La Barca', 'author': 'Trio Cristal'},
#  {'rank': '22', 'name': 'O Barquinho', 'author': 'João Gilberto'},
#  {'rank': '23', 'name': 'Runaway', 'author': 'Del Shannon'},
#  {'rank': '24', 'name': 'My Home Town', 'author': 'Paul Anka'},
#  {'rank': '25', 'name': 'Corinna, corinna', 'author': 'Demetrius'},
#  {'rank': '26', 'name': 'Coração De Luto', 'author': 'Teixerinha'},
#  {'rank': '27', 'name': 'Agora', 'author': 'Alcides Gerardi'},
#  {'rank': '28', 'name': 'Perdão Para Dois', 'author': 'Cauby Peixoto'},
#  {'rank': '29',
#   'name': 'Perdoa-me Pelo Bem, Que Te Quero',
#   'author': 'Orlando Dias'},
#  {'rank': '30', 'name': 'Poema Do Adeus', 'author': 'Miltinho'},
#  {'rank': '31', 'name': 'Bata Baby', 'author': 'Wilson Miranda'},
#  {'rank': '32', 'name': 'Wonderland By Night', 'author': 'Bert Kaempfert'},
#  {'rank': '33', 'name': 'Ternura Antiga', 'author': 'Tito Madi'},
#  {'rank': '34', 'name': 'Só Vou De Mulher', 'author': 'Os Cariocas'},
#  {'rank': '35', 'name': 'Água De Beber', 'author': 'Isaura Garcia'},
#  {'rank': '36', 'name': 'Pony Time', 'author': 'Chubby Checker'},
#  {'rank': '37', 'name': 'Never On Sunday', 'author': 'Melina Mercouri'},
#  {'rank': '38', 'name': 'Michael', 'author': 'The Highwaymen'},
#  {'rank': '39', 'name': 'G.i.blues', 'author': 'Elvis Presley'},
#  {'rank': '40', 'name': 'Aliança', 'author': 'Fernando Barreto'},
#  {'rank': '41', 'name': 'Marcha Do Pintinho', 'author': 'Emilinha Borba'},
#  {'rank': '42', 'name': 'A Noiva', 'author': 'Angela Maria'},
#  {'rank': '43', 'name': 'Ninguém Chora Por Mim', 'author': 'Moacyr Franco'},
#  {'rank': '44', 'name': 'O Amor Em Paz', 'author': 'João Gilberto'},
#  {'rank': '45', 'name': 'Olga', 'author': 'Os Cometas'},
#  {'rank': '46', 'name': 'Wheels', 'author': 'String-a-longs'},
#  {'rank': '47', 'name': 'O Amor Em Paz', 'author': 'João Gilberto'},
#  {'rank': '48', 'name': 'Amor Impossível', 'author': 'Carlos Nobre'},
#  {'rank': '49', 'name': 'Cadeira Vazia', 'author': 'Elza Soares'},
#  {'rank': '50', 'name': 'Dinah', 'author': 'Clério Morais'},
#  {'rank': '51', 'name': 'Abismo De Rosas', 'author': 'Dilermando Reis'},
#  {'rank': '52', 'name': 'Ironia', 'author': 'Carlos Nobre'},
#  {'rank': '53', 'name': 'Apache', 'author': 'The Shadows'},
#  {'rank': '54', 'name': 'Tenho Ciúme De Tudo', 'author': 'orlando Dias'},
#  {'rank': '55', 'name': 'Justiça De Deus', 'author': 'Leila Silva'},
#  {'rank': '56', 'name': 'Lágrimas de palhaço', 'author': 'Osny Silva'},
#  {'rank': '57',
#   'name': 'Never On Sunday',
#   'author': 'Don Costa And His Orchestra And Chorus'},
#  {'rank': '58', 'name': 'Paciência', 'author': 'Osny Silva'},
#  {'rank': '59', 'name': 'Green Fields', 'author': 'Os Cantores De Ébano'},
#  {'rank': '60',
#   'name': 'Maria Chiquinha',
#   'author': 'Sonia Mamede & Evaldo Gouveia'},
#  {'rank': '61', 'name': 'Poema Das Mãos', 'author': 'Moacyr Franco'},
#  {'rank': '62',
#   'name': 'Leva Eu Sodade',
#   'author': 'Nilo Amaro e Os Cantores do Ébano'},
#  {'rank': '63', 'name': 'Run Samson Run', 'author': 'Neil Sedaka'},
#  {'rank': '64', 'name': 'Saudade', 'author': 'Dalva De Oliveira'},
#  {'rank': '65', 'name': 'Louco Por Você', 'author': 'Roberto Carlos'},
#  {'rank': '66', 'name': 'A Lua É Dos Namorados', 'author': 'Ângela Maria'},
#  {'rank': '67', 'name': 'O Bom Menino', 'author': 'Carequinha'},
#  {'rank': '68', 'name': 'Abaixo De Deus', 'author': 'Jorge Veiga'},
#  {'rank': '69', 'name': 'Amargo retorno', 'author': 'Trio Cristal'},
#  {'rank': '70', 'name': 'Seria Tão Diferente', 'author': 'Núbia Lafayette'},
#  {'rank': '71', 'name': 'Analfabeta Em Amor', 'author': 'Ellen De Lima'},
#  {'rank': '72', 'name': 'Não Sabemos', 'author': 'Leila Silva'},
#  {'rank': '73',
#   'name': 'As Folhas Verdes De Verão',
#   'author': 'Wilma Bentivegna'},
#  {'rank': '74', 'name': 'Quero Morrer No Carnaval', 'author': 'Linda Batista'},
#  {'rank': '75', 'name': 'Devolvi', 'author': 'Núbia Lafayette'},
#  {'rank': '76', 'name': 'Ave Maria', 'author': 'Dalva De Oliveira'},
#  {'rank': '77', 'name': 'Me Leva Pro Ceu', 'author': 'Emilinha Borba'},
#  {'rank': '78', 'name': 'Não Me Envergonho', 'author': 'Osny Silva'},
#  {'rank': '79', 'name': 'Zé Bonitinho', 'author': 'Jorge Loredo'},
#  {'rank': '80', 'name': 'Beija Me Depois', 'author': 'Anísio Silva'},
#  {'rank': '81', 'name': 'Deixa Andar', 'author': 'Elizeth Cardoso'},
#  {'rank': '82', 'name': 'Rock Do Ratinho', 'author': 'Carequinha'},
#  {'rank': '83', 'name': 'Borrasca', 'author': 'Angela Maria'},
#  {'rank': '84', 'name': 'Bouddha', 'author': 'The Jordans'},
#  {'rank': '85', 'name': 'Minhas namoradas', 'author': 'Cauby Peixoto'},
#  {'rank': '86',
#   'name': 'Save the last dance for me',
#   'author': 'Ronnie Lummer'},
#  {'rank': '87', 'name': 'Rock Do Saci', 'author': 'Demetrius'},
#  {'rank': '88', 'name': 'Alma De Boêmio', 'author': 'José Orlando'},
#  {'rank': '89', 'name': 'Cansei De Rock', 'author': 'Nora Ney'},
#  {'rank': '90', 'name': 'Eu já te vi', 'author': 'Rogéria'},
#  {'rank': '91', 'name': 'Castiguei', 'author': 'Altamiro Carrilho'},
#  {'rank': '92', 'name': 'My Love For You', 'author': 'Johnny Mathis'},
#  {'rank': '93', 'name': 'Chega', 'author': 'Carlos Augusto'},
#  {'rank': '94', 'name': 'Hey Mama', 'author': 'Celly Campello'},
#  {'rank': '95',
#   'name': 'Fica Comigo Esta Noite',
#   'author': 'Nelson Gonçalves'},
#  {'rank': '96', 'name': 'Per Omnia Saecula', 'author': 'Carminha Mascarenhas'},
#  {'rank': '97', 'name': 'Triste Regresso', 'author': 'Leo Belico'},
#  {'rank': '98', 'name': 'Näo Sou De Nada', 'author': 'Fernando Costa'},
#  {'rank': '99', 'name': 'Poema das mãos', 'author': 'João Dias'},
#  {'rank': '100', 'name': 'Não deixe a peteca cair', 'author': 'Trio Irakitan'}]
